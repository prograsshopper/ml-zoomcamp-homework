# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Accuracy

# %%
class MyFakeClassifier(BaseEstimator):
    def fit(self, X, y):
        pass

    # 입력값으로 들어오는 X 데이터셋의 크기만큼 모두 0으로 만들어서 반환
    def predict(self, X):
        return np.zeros((len(X), 1), dtype=bool)

# 사이킷런의 내장 데이터넷을 이용해 MNIST 데이터 로딩
digits = load_digits()

# digits 번호가 7번이면 True & astype(int)로 1로 변환, 7번이 아니면 False고 0으로 변환
y = (digits.target == 7).astype(int)
X_train, X_test, y_train, y_test = train_test_split(digits.data, y, random_state=11)

# %%
# 예측과 평가 수행
# 1. 뷸균형한 레이블 데이터 분포도 확인
print(f'Size Of Label Test Data: {y_test.shape}')
print(f'테스트 세트 레이블 0과 1의 분포도')
print(pd.Series(y_test).value_counts())

# Dummy Classifier로 학습/예측/정확도 평가
fakeClf = MyFakeClassifier()
fakeClf.fit(X_train, y_train)
fakepred = fakeClf.predict(X_test)
print(f"모든 예측을 0으로 해도 정확도는: {accuracy_score(y_test, fakepred)}")
# Out:
# Size Of Label Test Data: (450,)
# 테스트 세트 레이블 0과 1의 분포도
# 0    405
# 1     45
# Name: count, dtype: int64
# 모든 예측을 0으로 해도 정확도는: 0.9

# %% [markdown]
# # 오차행렬

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, fakepred)
# Out:
# array([[405,   0],
#        [ 45,   0]])

# %% [markdown]
# # 정밀도와 재현율

# %% [markdown]
# from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
#
# def get_clf_eval(y_test, pred):
#     confusion = confusion_matrix(y_test, pred)
#     accuracy = accuracy_score(y_test, pred)
#     precision = precision_score(y_test, pred)
#     recall = recall_score(y_test, pred)
#     print(f"오차행렬: {confusion}")
#     print(f"정확도: {accuracy}, 정밀도: {precision}, 재현율: {recall}")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

titanic_df = pd.read_csv('titanic_train.csv')
y_titanic_df = titanic_df['Survived']
X_titanic_df = titanic_df.drop('Survived', axis=1)
X_titanic_df = X_titanic_df.fil

X_train, X_test, y_train, y_test = Train_test_split(X_titanic_df, y_titanic_Df, test_size=0.20, random_state=11)
lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)
pred = lr_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       6 y_titanic_df = titanic_df['Survived']
#       7 X_titanic_df = titanic_df.drop('Survived', axis=1)
# ----> 8 X_titanic_df = transform_features(X_titanic_df)
#      10 X_train, X_test, y_train, y_test = Train_test_split(X_titanic_df, y_titanic_Df, test_size=0.20, random_state=11)
#      11 lr_clf = LogisticRegression()
#
# NameError: name 'transform_features' is not defined

# %% [markdown]
# # F1 Score
